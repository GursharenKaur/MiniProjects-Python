# %% [markdown]
# <a href="https://colab.research.google.com/github/GursharenKaur/MiniProjects-Python/blob/main/Combo_Finder.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **COMBO FINDER**

# %% [markdown]
# Find all the list of products whose sum-of-price is between 290 and 310.
#
# ProductList = {p1:10, p2:15, p3:20, p4:25, p5:30, p6:35, p7:50}

# %%
import random as r

ProductList = {'p1':10, 'p2':15, 'p3':20, 'p4':25, 'p5':30, 'p6':35, 'p7':50}
for i in range(1000):
  prices = list(ProductList.keys())
  size = r.randint(2,len(ProductList)-1)

  L=r.sample(prices,size)

  sumProduct = sum(ProductList[i] for i in L)
  if (sumProduct>=100) and (sumProduct<=120):
    print(L, "sum= ", sumProduct)
# Out:
# ['p1', 'p5', 'p3', 'p4', 'p6'] sum=  120
# ['p3', 'p1', 'p4', 'p6', 'p2'] sum=  105
# ['p7', 'p3', 'p5'] sum=  100
# ['p3', 'p7', 'p6'] sum=  105
# ['p3', 'p7', 'p5'] sum=  100
# ['p4', 'p7', 'p5', 'p2'] sum=  120
# ['p7', 'p1', 'p3', 'p4'] sum=  105
# ['p7', 'p6', 'p4', 'p1'] sum=  120
# ['p2', 'p6', 'p3', 'p5'] sum=  100
# ['p7', 'p2', 'p6'] sum=  100
# ['p6', 'p5', 'p4', 'p1'] sum=  100
# ['p5', 'p7', 'p3', 'p1'] sum=  110
# ['p4', 'p3', 'p7', 'p1'] sum=  105
# ['p1', 'p4', 'p5', 'p6', 'p2'] sum=  115
# ['p5', 'p4', 'p1', 'p7'] sum=  115
# ['p3', 'p6', 'p4', 'p2', 'p1'] sum=  105
# ['p2', 'p4', 'p5', 'p6'] sum=  105
# ['p7', 'p2', 'p1', 'p4'] sum=  100
# ['p5', 'p1', 'p7', 'p2'] sum=  105
# ['p1', 'p6', 'p5', 'p4'] sum=  100
# ['p6', 'p1', 'p2', 'p7'] sum=  110
# ['p4', 'p6', 'p5', 'p1', 'p2'] sum=  115
# ['p1', 'p4', 'p2', 'p6', 'p5'] sum=  115
# ['p2', 'p1', 'p4', 'p7'] sum=  100
# ['p5', 'p4', 'p3', 'p1', 'p2'] sum=  100
# ['p5', 'p4', 'p6', 'p2'] sum=  105
# ...
